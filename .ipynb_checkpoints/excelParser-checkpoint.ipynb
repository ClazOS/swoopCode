# %%
import pandas as pd
import numpy as np

# %%
#import excel data at (path, sheet)
ledge = pd.read_excel('/Users/swoop/Dropbox/Triton Logistics/Docs/Accounting/Master Ledger 2014.xlsx', 'SEP')

# %%
ledge.head() #show what I have
# Out:
#   September '14 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0           NaN        NaN        NaN        NaN        NaN          NaN
# 1           NaN        NaN        NaN        NaN        NaN          NaN
# 2          DATE    AUTH BY      PAYEE  DEBT TYPE       DEBT  CREDIT TYPE
# 3       30/9/14         GW     Repsol       Fuel         30         Cash
# 4           NaN        NaN        NaN        NaN        NaN          NaN
#
#   Unnamed: 6 THIS ACCOUNT IS CURRENTLY BALANCED  Unnamed: 9 Unnamed: 10  \
# 0        NaN           RUNNING BALANCE        0         NaN         NaN
# 1        NaN                       NaN      NaN         NaN         NaN
# 2     CREDIT                  COMMENTS  BALANCE         NaN         NaN
# 3         30                       NaN        0         NaN     Example
# 4        NaN                       NaN        0         NaN        DATE
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  Unnamed: 15 Unnamed: 16  \
# ...

# %%
report = ledge.pivot_table(values=['CREDIT TYPE'],index=['CREDIT'],columns=['BALANCE'], fill_value=0, aggfunc=np.sum)
report.head(n=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-edbd6796fb15> in <module>()
# ----> 1 report = ledge.pivot_table(values=['CREDIT TYPE'],index=['CREDIT'],columns=['BALANCE'], fill_value=0, aggfunc=np.sum)
#       2 report.head(n=10)
#
# /Library/Python/2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      58                 else:
#      59                     kwargs[new_arg_name] = old_arg_value
# ---> 60             return func(*args, **kwargs)
#      61         return wrapper
#      62     return _deprecate_kwarg
#
# /Library/Python/2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#      58                 else:
#      59                     kwargs[new_arg_name] = old_arg_value
# ---> 60             return func(*args, **kwargs)
#      61         return wrapper
#      62     return _deprecate_kwarg
#
# ...

# %%
#export back to excel (source, sheet)
pd.DataFrame(report).to_excel('/Users/swoop/Dropbox/Triton Logistics/Docs/Accounting/Master Ledger 2014.xlsx', sheet_name='Sheet1')
